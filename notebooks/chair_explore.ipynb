# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
cap = cv.VideoCapture('../bon_exemple.mp4')
_ ,frame = cap.read()

# %%
frame.shape
# Out:
# (720, 1280, 3)

# %%
cv.imshow('frame', frame[0:580,:])

# %%
plt.imshow(frame[200:400,850:1100])

# %%
plt.imshow(frame[80:250,700:900])

# %%
plt.imshow(frame[0:110,750:850])
