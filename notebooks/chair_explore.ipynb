# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
cap = cv.VideoCapture('../true_test.mp4')
_ ,frame = cap.read()

# %%
frame.shape
# Out:
# (1080, 1920, 3)

# %%
frame = cv.rectangle(frame,(900, 100), (1920,1000), (0,0,255),8 )

# %%
cv.imshow('frame', frame[100:1000,900:1920])
cv.waitKey(1)
# Out:
# -1

# %%
plt.imshow(frame)
